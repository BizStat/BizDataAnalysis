# %% [markdown]
# # 제1장 **파이썬을 이용한 데이터분석 소개**

# %% [markdown]
# ###  ChatGPT를 이용한 파이썬 프로그램 작성 사례

# %% [markdown]
# (1) 파이썬으로 작성한 간단한 계산기 프로그램

# %%
def add(x, y):
    return x + y

def subtract(x, y):
    return x - y

def multiply(x, y):
    return x * y

def divide(x, y):
    if y == 0:
        return "Error: Division by zero!"
    return x / y

print("간단한 계산기 프로그램입니다.")
print("사칙 연산을 선택하세요:")
print("1. 더하기")
print("2. 빼기")
print("3. 곱하기")
print("4. 나누기")

while True:
    choice = input("원하는 연산을 선택하세요 (1/2/3/4): ")

    if choice in ('1', '2', '3', '4'):
        num1 = float(input("첫 번째 숫자를 입력하세요: "))
        num2 = float(input("두 번째 숫자를 입력하세요: "))

        if choice == '1':
            print("결과:", add(num1, num2))
        elif choice == '2':
            print("결과:", subtract(num1, num2))
        elif choice == '3':
            print("결과:", multiply(num1, num2))
        elif choice == '4':
            print("결과:", divide(num1, num2))

        break
    else:
        print("올바른 연산자를 선택하세요.")

# %% [markdown]
# (2) 계산기 프로그램을 GUI 형태로 수정

# %%
import tkinter as tk

def calculate():
    try:
        num1 = float(entry1.get())
        num2 = float(entry2.get())
        operation = operation_var.get()

        if operation == "+":
            result = num1 + num2
        elif operation == "-":
            result = num1 - num2
        elif operation == "*":
            result = num1 * num2
        elif operation == "/":
            if num2 == 0:
                result = "Error: Division by zero!"
            else:
                result = num1 / num2

        result_label.config(text="Result: " + str(result))
    except ValueError:
        result_label.config(text="Error: Invalid input")

# GUI 생성
root = tk.Tk()
root.title("간단한 계산기")

# 두 개의 숫자 입력 필드
entry1 = tk.Entry(root)
entry1.pack(pady=5)
entry2 = tk.Entry(root)
entry2.pack(pady=5)

# 연산 선택 옵션 메뉴
operation_var = tk.StringVar(root)
operation_var.set("+")  # 초기값 설정
operation_menu = tk.OptionMenu(root, operation_var, "+", "-", "*", "/")
operation_menu.pack(pady=5)

# 계산 버튼
calculate_button = tk.Button(root, text="Calculate", command=calculate)
calculate_button.pack(pady=5)

# 결과 표시 레이블
result_label = tk.Label(root, text="Result: ")
result_label.pack(pady=5)

root.mainloop()

# %% [markdown]
# (3) 파이썬으로 구현한 워드 클라우드

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

text = "Python is a widely used programming language in the fields of artificial intelligence and natural language processing. Word cloud is one of the useful tools for visualizing text data. Creating a word cloud with Python is simple and effective"

wordcloud = WordCloud(background_color='white').generate(text)

plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')  # 축 제거
plt.show()

# %% [markdown]
# * 구글 코랩 운영 환경에 대한 정보 출력

# %%
# !cat /etc/issue.net

# %%
# !cat /proc/cpuinfo

# %% [markdown]
# # 파이썬 실행결과에서 한글깨짐 현상

# %% [markdown]
# *  현재 사용 중인 폰트(글꼴) 가운데 한글 폰트 출력

# %%
# !fc-list :lang=ko

# %% [markdown]
# *  나눔 글꼴 설치

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -f -v

# %% [markdown]
# * 설치된 나눔 글꼴 확인

# %%
# !fc-list :lang=ko

# %% [markdown]
# * 설치된 나눔 글꼴 확인을 위한 또다른 방법

# %%
# !fc-list | grep -i nanum

# %% [markdown]
# * 설치된 한글 글꼴을 지정하여 한글 워드 클라우드를 작성한 사례

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# 나눔 폰트 경로 설정
font_path = "/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf"

# 텍스트 데이터 예시
text = "경기대학교 경영학전공은 마케팅, 생산관리, 인사조직, 재무, 회계, 국제경영 \
등 경영학 전반에 걸쳐 교육하고 있으며, 지금까지 경영학전공을 거쳐 간 졸업생들은 \
사회각계각층에서 큰 활약을 하고 있습니다. 경영학전공은 21세기를 대표하는 경영인을 \
양성하기 위하여 창의적이고 진취적인 기업가 정신 및 전문 직업의식의 고취, 올바른 \
기업윤리 정신과 건전한 함양, 전문적이고 실용적인 경영학 지식, 어학능력을 배양하고자 \
노력하고 있습니다"

# 워드 클라우드 생성
wordcloud = WordCloud(width=800, height=400, background_color='white',font_path=font_path).generate(text)

# 워드 클라우드 이미지 표시
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# 워드 클라우드 이미지 파일로 저장
wordcloud.to_file("wordcloud_example.png")

# %% [markdown]
# * matplotlib를 이미 불러와 사용했다면 한글 글꼴 환경을 matplotlib에 반영하기 위해 다음과 같이 캐시를 삭제할 필요가 있음

# %%
# !rm ~/.cache/matplotlib -rf

# %% [markdown]
# * 한글 그래프 환경 적용을 위해 세션 다시 시작
#   - 위의 메뉴에서 [런타임] -> [세션 다시 시작] 을 선택하거나 [Control] + M 을 누르면 됨

# %% [markdown]
# * matplotlib 라이브러리를 이용해 그래프를 작성할 때 한글 폰트를 사용하도록 다음과 같은 코드를 실행하여 환경을 설정

# %%
from matplotlib import rc
rc('font', family='NanumMyeongjo')

# %% [markdown]
# * 이후에 실행하는 matplotlib 라이브러리를 이용한 그래프에서는 한글을 표현할 수 있음

# %%
import numpy as np
import matplotlib.pyplot as plt


# 데이터 생성
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]

# 그래프 그리기
plt.plot(x, y)

# 그래프 제목과 축 레이블 추가
plt.title('간단한 선 그래프')
plt.xlabel('X 축')
plt.ylabel('Y 축')

# 그래프 표시
plt.show()

# %% [markdown]
# # 구글 코랩에서 외부 파일 사용하기

# %% [markdown]
# * 구글 코랩 노트북에서 현재 사용하고 있는 폴더 확인을 위한 명령

# %%
# !pwd

# %% [markdown]
# * 자신의 구글 드라이브를 현재 사용 중인 구글 코랩 폴더에 마운트하기 위한 코드

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# * 현재 작업 중인 구글 코랩 폴더의 내용을 보기 위한 명령

# %%
# !ls

# %% [markdown]
# # 파이썬 프로그래밍 기초

# %%
money = input('당신은 충분한 돈을 가지고 있습니까? (y/n)')
if money == 'y':
  print("택시타고 가도 좋습니다.")
else:
  print("뛰어 가세요!")

# %%
items = ['개','고양이','사자','코끼리']
for i in items:
  print(i)

# %%
student = [('철수',90),('영희',95),('고양',50),('사자',70),('표범',25)]
for (name, score) in student:
  if score >= 80:
    print(name)

# %% [markdown]
# ### 노트북의 모든 코드의 실행 결과 삭제

# %%
from google.colab import output
output.clear()
